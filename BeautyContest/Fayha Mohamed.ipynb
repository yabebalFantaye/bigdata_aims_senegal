# %%
#------ Fayha Mohamed.py -------
#  code starts below this
#-------------------------------------------
import numpy as np 
def A_guess (History=None):
    return 50
def B_guess (History=None):
    return np.random.randint(1,100)

# %%
for i in range (100):
    C1 =A_guess()
    C2 =B_guess()
    Ca=[C1,C2]
    print C1 , C2, np.mean(Ca)
# Out:
# 50 75 62.5
# 50 9 29.5
# 50 56 53.0
# 50 35 42.5
# 50 85 67.5
# 50 85 67.5
# 50 14 32.0
# 50 56 53.0
# 50 45 47.5
# 50 17 33.5
# 50 36 43.0
# 50 3 26.5
# 50 78 64.0
# 50 43 46.5
# 50 69 59.5
# 50 94 72.0
# 50 34 42.0
# 50 39 44.5
# 50 79 64.5
# 50 50 50.0
# 50 45 47.5
# 50 17 33.5
# 50 33 41.5
# 50 78 64.0
# 50 4 27.0
# 50 34 42.0
# 50 54 52.0
# 50 93 71.5
# 50 46 48.0
# 50 50 50.0
# 50 8 29.0
# 50 68 59.0
# 50 29 39.5
# 50 42 46.0
# 50 79 64.5
# 50 25 37.5
# 50 70 60.0
# 50 51 50.5
# 50 56 53.0
# 50 94 72.0
# 50 15 32.5
# 50 83 66.5
# 50 53 51.5
# 50 57 53.5
# 50 91 70.5
# 50 41 45.5
# 50 42 46.0
# 50 8 29.0
# 50 55 52.5
# 50 14 32.0
# 50 87 68.5
# 50 68 59.0
# 50 47 48.5
# 50 4 27.0
# 50 80 65.0
# 50 89 69.5
# 50 91 70.5
# 50 44 47.0
# 50 38 44.0
# 50 24 37.0
# 50 82 66.0
# 50 15 32.5
# 50 43 46.5
# 50 89 69.5
# 50 94 72.0
# 50 88 69.0
# 50 24 37.0
# 50 35 42.5
# 50 18 34.0
# 50 55 52.5
# 50 55 52.5
# 50 23 36.5
# 50 9 29.5
# 50 14 32.0
# 50 90 70.0
# 50 8 29.0
# 50 39 44.5
# ...
